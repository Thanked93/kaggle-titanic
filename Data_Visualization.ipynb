# %%
import numpy as np
import pandas as pd

# read the csv
df = pd.read_csv('./titanic/train.csv')
# Out:
#   File "<ipython-input-6-f5d3c1ba8a1d>", line 4
#     // read the csv
#      ^
# SyntaxError: invalid syntax

# %%
# which has missing data
[col for col in df.columns if df[col].isnull().any()]
# Out:
# ['Age', 'Cabin', 'Embarked']
